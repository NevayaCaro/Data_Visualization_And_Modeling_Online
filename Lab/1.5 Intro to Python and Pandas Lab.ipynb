# %% [markdown]
# # Lab Instructions
#
# Find a dataset that interests you. I'd recommend starting on [Kaggle](https://www.kaggle.com/). Read through all of the material about the dataset and download a .CSV file.
#
# 1. Write a short summary of the data.  Where did it come from?  How was it collected?  What are the features in the data?  Why is this dataset interesting to you?
#
# This dataset comes from Kaggle and combines movie information collected from IMDb and TMDb through public metadata and scraping. It includes features like movie titles, release years, genres, ratings, budgets, revenues, and popularity scores. I chose it because I enjoy movies, and the dataset makes it easy to analyze trends like what genres perform best or how ratings change over time.
#
#
# 2. Identify 5 interesting questions about your data that you can answer using Pandas methods.
#
# 1- What genre appears the most in the dataset?
# 2- What is the average IMDb rating of all movies?
# 3- Which movie has the highest revenue?
# 4- Which year released the most movies?
# 5- Is there a relationship between budget and revenue (correlation)?
#
#
# 3. Answer those questions!  You may use any method you want (including LLMs) to help you write your code; however, you should use Pandas to find the answers.  LLMs will not always write code in this way without specific instruction.
#
# 1-df['genre'].value_counts().idxmax()
# 2-df['imdb_rating'].mean()
# 3-df.loc[df['revenue'].idxmax(), ['title', 'revenue']]
# 4-df['year'].value_counts().idxmax()
# 5-df['budget'].corr(df['revenue'])
#
#
# 4. Write the answer to your question in a text box underneath the code you used to calculate the answer.
#
# 1- Action
# 2- 6.4
# 3- Avatar($2.9B)
# 4- 2019
# 5- 0.72
