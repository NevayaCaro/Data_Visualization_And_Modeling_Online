# %% [markdown]
# # Lab Instructions
#
# Create 3 visualizations from text data of your choice.  Each visualization should have at least 1 - 2 sentences explaining both the figure and the interpretation.
# You may use any LLM and produce whatever visuals you think best illustrate your data.

# %%
plt.figure()
plt.bar(labels, values)
plt.title("Top 5 Most Common Words")
plt.xlabel("Word")
plt.ylabel("Frequency")
plt.savefig("top_words.png")
plt.show()

# %%
Top 5 Most Common Words

# %%
This bar chart shows the 
five most frequently occurring words 
in the selected text data. The height of 
each bar represents how often each word appears.
Interpretation:
The word “text” appears most frequently, 
indicating that the passage is strongly centered 
around discussing text itself. This helps identify 
key themes and important terms within the data.

# %%
Word Length Distribution

# %%
plt.figure()
plt.hist(word_lengths, bins=5)
plt.title("Word Length Distribution")
plt.xlabel("Word Length")
plt.ylabel("Count")
plt.savefig("word_length_distribution.png")
plt.show()

# %%
This histogram displays the distribution 
of word lengths found in the text. Each bar 4
represents how many words fall within a certain 
length range.
Interpretation:
Most words are relatively short, which is typical 
for general English text. This suggests the passage
is readable and not overly technical or complex in 
vocabulary.

# %%
plt.figure()
plt.bar(["Unique Words", "Repeated Words"], [unique_words, repeated_words])
plt.title("Unique vs Repeated Words")
plt.ylabel("Count")
plt.savefig("unique_vs_repeated_words.png")
plt.show()

# %%
Unique vs Repeated Words

# %%
This bar chart compares the number of words 
that appear only once versus words that are 
repeated multiple times in the text.
Interpretation:
The text contains many more unique words than 
repeated ones, showing a diverse vocabulary. 
However, the repeated words likely represent 
the main ideas emphasized in the passage.
